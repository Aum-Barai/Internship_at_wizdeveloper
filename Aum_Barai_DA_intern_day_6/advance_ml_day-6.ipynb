# %% [markdown]
# ## import nesssecary libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris, load_wine
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.decomposition import PCA
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
import seaborn as sns

# %%
# Load Iris dataset
iris = load_iris()
X_iris, y_iris = iris.data, iris.target

# Split the Iris dataset into training and testing sets
X_train_iris, X_test_iris, y_train_iris, y_test_iris = train_test_split(X_iris, y_iris, test_size=0.2, random_state=42)

# %%
# Load Wine dataset
wine = load_wine()
X_wine, y_wine = wine.data, wine.target

# Split the Wine dataset into training and testing sets
X_train_wine, X_test_wine, y_train_wine, y_test_wine = train_test_split(X_wine, y_wine, test_size=0.2, random_state=42)

# %%
# Random Forest Classifier
rf_model = RandomForestClassifier(n_estimators=100, random_state=42)
rf_model.fit(X_train_iris, y_train_iris)
y_pred_rf = rf_model.predict(X_test_iris)
rf_accuracy = accuracy_score(y_test_iris, y_pred_rf)
rf_conf_matrix = confusion_matrix(y_test_iris, y_pred_rf)
rf_class_report = classification_report(y_test_iris, y_pred_rf)

# %%
# Gradient Boosting Classifier
gb_model = GradientBoostingClassifier(n_estimators=100, random_state=42)
gb_model.fit(X_train_iris, y_train_iris)
y_pred_gb = gb_model.predict(X_test_iris)
gb_accuracy = accuracy_score(y_test_iris, y_pred_gb)
gb_conf_matrix = confusion_matrix(y_test_iris, y_pred_gb)
gb_class_report = classification_report(y_test_iris, y_pred_gb)

# %%
# PCA for Wine dataset
pca = PCA(n_components=2)
X_train_wine_pca = pca.fit_transform(X_train_wine)
X_test_wine_pca = pca.transform(X_test_wine)

# %%
# Random Forest Confusion Matrix

sns.heatmap(rf_conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=iris.target_names, yticklabels=iris.target_names)
plt.title('Random Forest Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
# Out:
# Text(50.722222222222214, 0.5, 'Actual')

# %%
# Gradient Boosting Confusion Matrixplt.legend(handles=scatter.legend_elements()[0], labels=wine.target_names.tolist())
sns.heatmap(gb_conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=iris.target_names, yticklabels=iris.target_names)
plt.title('Gradient Boosting Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
# Out:
# Text(50.722222222222214, 0.5, 'Actual')

# %%
# PCA for Wine dataset

scatter = plt.scatter(X_train_wine_pca[:, 0], X_train_wine_pca[:, 1], c=y_train_wine, cmap='viridis', edgecolor='k', s=150)
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.title('PCA of Wine Dataset')
plt.legend(handles=scatter.legend_elements()[0], labels=wine.target_names.tolist())
plt.colorbar(scatter)

# %%
# Random Forest Classification Report
plt.axis('off')
plt.text(0.5, 0.5, rf_class_report, ha='center', va='center', wrap=True, fontsize=12)
plt.title('Random Forest Classification Report')
# Out:
# Text(0.5, 1.0, 'Random Forest Classification Report')

# %%
# Gradient Boosting Classification Report
plt.axis('off')
plt.text(0.5, 0.5, gb_class_report, ha='center', va='center', wrap=True, fontsize=12)
plt.title('Gradient Boosting Classification Report')
# Out:
# Text(0.5, 1.0, 'Gradient Boosting Classification Report')

# %%
# PCA Explained Variance
explained_variance = pca.explained_variance_ratio_
components = np.arange(1, len(explained_variance) + 1)
plt.bar(components, explained_variance * 100, color='blue')
plt.xlabel('Principal Component')
plt.ylabel('Percentage of Explained Variance')
plt.title('PCA Explained Variance')
# Out:
# Text(0.5, 1.0, 'PCA Explained Variance')

# %%
# Print accuracies
print(f"Random Forest Accuracy on Iris dataset: {rf_accuracy:.2f}")
print(f"Gradient Boosting Accuracy on Iris dataset: {gb_accuracy:.2f}")
# Out:
# Random Forest Accuracy on Iris dataset: 1.00
# Gradient Boosting Accuracy on Iris dataset: 1.00
